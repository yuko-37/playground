# %%
# !curl --request POST \
  --url 'https://api.vkvideo.ru/method/video.getFromAlbum?v=5.275&client_id=52461373' \
  --header 'Content-Type: application/x-www-form-urlencoded' \
  --data album_id=10 \
  --data count=25 \
  --data extended=1 \
  --data fields=is_esia_verified,is_sber_verified,is_tinkoff_verified,photo_50,verified \
  --data offset=0 \
  --data owner_id=-217878975 \
  --data sort_album=0 \
  --data access_token=anonym.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhbm9ueW1faWQiOjEwNzMyMjA0NTYsImFwcF9pZCI6NTI0NjEzNzMsImlhdCI6MTc3NTU0OTc0OCwiaXNfdmVyaWZpZWQiOmZhbHNlLCJleHAiOjE3NzU2MzYxNDgsInNpZ25lZF90aW1lIjpudWxsLCJhbm9ueW1faWRfbG9uZyI6OTExMDg3NDE0NDcxODIyNzU5Niwic2NvcGUiOjc4ODEyOTkzNDc4OTgzNjh9.k0z9k9nZO15AvN0-eunNnYCs1BU_iUJo6wVmR0cyXMU \
| jq . > resp.txt

# %%
import requests
import json

# %%
with open('resp.txt', 'r', encoding='utf-8') as f:
    data = json.load(f)

items = data.get('response', {}).get('items', [])
titles = [item['video']['title'] for item in items if 'video' in item and 'title' in item['video']]
print(titles)

# %%
import requests


def get_token():
    url = "https://login.vk.com/"
    
    params = {
        "act": "get_anonym_token"
    }

    data = {
        "client_secret": "o557NLIkAErNhakXrQ7A",
        "client_id": "52461373",
        "scopes": "audio_anonymous,video_anonymous,photos_anonymous,profile_anonymous",
        "isApiOauthAnonymEnabled": "false",
        "version": "1",
        "app_id": "6287487"
    }

    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }

    response = requests.post(url, params=params, data=data, headers=headers)
    
    response.raise_for_status()  # выбросит ошибку при не-200
    
    return response.json()

# %%
from tokenprovider import get_token
get_token()

# %%
from dataprovider import get_titles

get_titles(-212451998, 9)
